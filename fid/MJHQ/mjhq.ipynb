# %%
from datasets import load_dataset
ds = load_dataset("playgroundai/MJHQ-30K", split="valid")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Resolving data files:   0%|          | 0/20 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/20 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/20 [00:00<?, ?files/s]
# data/test-00000-of-00020.parquet:   0%|          | 0.00/489M [00:00<?, ?B/s]
# data/test-00001-of-00020.parquet:   0%|          | 0.00/496M [00:00<?, ?B/s]
# data/test-00002-of-00020.parquet:   0%|          | 0.00/539M [00:00<?, ?B/s]
# data/test-00003-of-00020.parquet:   0%|          | 0.00/532M [00:00<?, ?B/s]
# data/test-00004-of-00020.parquet:   0%|          | 0.00/416M [00:00<?, ?B/s]
# data/test-00005-of-00020.parquet:   0%|          | 0.00/416M [00:00<?, ?B/s]
# data/test-00006-of-00020.parquet:   0%|          | 0.00/282M [00:00<?, ?B/s]
# data/test-00007-of-00020.parquet:   0%|          | 0.00/286M [00:00<?, ?B/s]
# data/test-00008-of-00020.parquet:   0%|          | 0.00/524M [00:00<?, ?B/s]
# data/test-00009-of-00020.parquet:   0%|          | 0.00/522M [00:00<?, ?B/s]
# data/test-00010-of-00020.parquet:   0%|          | 0.00/576M [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# data/test-00011-of-00020.parquet:   0%|          | 0.00/581M [00:00<?, ?B/s]

# %%
from datasets import config
print(config.HF_DATASETS_CACHE)
# Out:
# /home/scpark/.cache/huggingface/datasets

# %%
from huggingface_hub import hf_hub_download

hf_hub_download(
  repo_id="playgroundai/MJHQ-30K", 
  filename="mjhq30k_imgs.zip", 
  local_dir="path/to/folder",
  repo_type="dataset"
)
