# %%
import torch
data = torch.load('/home/scpark/logpx_samplers/samplings/PixArt-Alpha/4.5/200/Euler/1000/train_traj_0/0.pt')
data.keys()

# %%
data['sample'].shape

# %%
data['sample'].shape

import matplotlib.pyplot as plt

plt.imshow(data['sample'][:3, :, :].permute(1, 2, 0).data.cpu().numpy())
plt.show()

# %%
samples = data['sample'].flatten().data.cpu().numpy()
import matplotlib.pyplot as plt
plt.hist(samples, bins=100)
plt.show()
