# %%
import os 
os.chdir('../../')

# %%
print('done')
# Out:
# done

# %%
from backbones.sana import SANA

# 사용 예
model = SANA(model_id='Efficient-Large-Model/Sana_600M_512px_diffusers')
print(model)

# %%
import matplotlib.pyplot as plt

def show_compare(euler_img, dpm_img, unipc_img):
    fig, axes = plt.subplots(1, 3, figsize=(18, 10))
    axes[0].imshow(euler_img); axes[0].axis('off'); axes[0].set_title('Euler')
    axes[1].imshow(dpm_img);  axes[1].axis('off'); axes[1].set_title('DPM-Solver')
    axes[2].imshow(unipc_img);  axes[2].axis('off'); axes[2].set_title('UniPC')
    plt.tight_layout()
    plt.show()

# %%
from solvers.others.euler_solver import Euler_Solver

pos_texts = ["A serene twilight view of a traditional Korean hanok village nestled between misty mountain slopes: curved midnight-blue tiled eaves, softly glowing paper lanterns swaying in the breeze; ancient pine trees arching over stone pathways; intricate wooden lattice windows casting delicate shadows; a lone scholar in flowing hanbok practicing calligraphy beside a koi pond with lotus petals drifting on the water; cinematic 8K ultra-realism with dynamic volumetric moonlight filtering through morning mist; painterly strokes blending classical Joseon-era ink wash with modern hyperrealism; shot on RED Monstro 8K, 50 mm f/1.2 lens; subtle film grain; maximum fidelity; emotional atmosphere."]
neg_texts = ["lowres, bad anatomy, deformed, blurry, pixelated, oversaturated, underexposed, overexposed, artifact, jpeg artifacts, watermark, text, logo, extra limbs, mutated hands, unnatural colors, noisy background, out of focus, poor composition, cultural clichés, stereotype exaggeration, flat lighting, glitch"]

noise_schedule = model.get_noise_schedule()
model_fn = model.get_model_fn(noise_schedule=noise_schedule, pos_conds=pos_texts, neg_conds=neg_texts, guidance_scale=4.5)
latents = model.get_noise(seeds=[42])
print(latents.shape)

NFE = 20
solver = Euler_Solver(noise_schedule, steps=NFE, skip_type='time_uniform_flow', flow_shift=3.0, algorithm_type="data_prediction")
euler_latents = solver.sample(latents, model_fn)['samples']
euler_samples = model.decode_vae(euler_latents)
euler_samples[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 neg_texts = ["lowres, bad anatomy, deformed, blurry, pixelated, oversaturated, underexposed, overexposed, artifact, jpeg artifacts, watermark, text, logo, extra limbs, mutated hands, unnatural colors, noisy background, out of focus, poor composition, cultural clichés, stereotype exaggeration, flat lighting, glitch"]
#       6 noise_schedule = model.get_noise_schedule()
# ----> 7 model_fn = model.get_model_fn(noise_schedule=noise_schedule, pos_conds=pos_texts, neg_conds=neg_texts, guidance_scale=4.5)
#       8 latents = model.get_noise(seeds=[42])
#       9 print(latents.shape)
#
# File ~/logpx_samplers/backbones/sana.py:106, in SANA.get_model_fn(self, noise_schedule, pos_conds, neg_conds, guidance_scale)
#      99 def get_model_fn(
#     100     self,
#     101     noise_schedule,
#    (...)    104     guidance_scale: float = 4.5,
#     105 ) -> Tuple[callable, NoiseScheduleFlow, torch.Tensor]:
# --> 106     embeds, attn_mask, neg_embeds, neg_mask = self.encode(pos_conds, neg_conds)
#     108     def inner_model_fn(x, t, cond, **kwargs):
#     109         with self.context:
#
# File ~/logpx_samplers/backbones/sana.py:60, in SANA.encode(self, pos_texts, neg_texts)
#      57 if neg_texts is None:
#      58     neg_texts = [""] * len(pos_texts)
# ---> 60 embeds, attn_mask, neg_embeds, neg_mask = self.pipe.encode_prompt(
#      61     prompt=pos_texts,
#      62     negative_prompt=neg_texts,
#      63     num_images_per_prompt=1,
#      64     do_classifier_free_guidance=True,
#      65     device=self.device
#      66 )
#      67 return embeds, attn_mask, neg_embeds, neg_mask
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/diffusers/pipelines/sana/pipeline_sana.py:386, in SanaPipeline.encode_prompt(self, prompt, do_classifier_free_guidance, negative_prompt, num_images_per_prompt, device, prompt_embeds, negative_prompt_embeds, prompt_attention_mask, negative_prompt_attention_mask, clean_caption, max_sequence_length, complex_human_instruction, lora_scale)
#     383 select_index = [0] + list(range(-max_length + 1, 0))
#     385 if prompt_embeds is None:
# --> 386     prompt_embeds, prompt_attention_mask = self._get_gemma_prompt_embeds(
#     387         prompt=prompt,
#     388         device=device,
#     389         dtype=dtype,
#     390         clean_caption=clean_caption,
#     391         max_sequence_length=max_sequence_length,
#     392         complex_human_instruction=complex_human_instruction,
#     393     )
#     395     prompt_embeds = prompt_embeds[:, select_index]
#     396     prompt_attention_mask = prompt_attention_mask[:, select_index]
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/diffusers/pipelines/sana/pipeline_sana.py:304, in SanaPipeline._get_gemma_prompt_embeds(self, prompt, device, dtype, clean_caption, max_sequence_length, complex_human_instruction)
#     301 prompt_attention_mask = text_inputs.attention_mask
#     302 prompt_attention_mask = prompt_attention_mask.to(device)
# --> 304 prompt_embeds = self.text_encoder(text_input_ids.to(device), attention_mask=prompt_attention_mask)
#     305 prompt_embeds = prompt_embeds[0].to(dtype=dtype, device=device)
#     307 return prompt_embeds, prompt_attention_mask
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/transformers/utils/generic.py:1064, in check_model_inputs.<locals>.wrapper(self, *args, **kwargs)
#    1061                 module.forward = make_capture_wrapper(module, original_forward, key, specs.index)
#    1062                 monkey_patched_layers.append((module, original_forward))
# -> 1064 outputs = func(self, *args, **kwargs)
#    1065 # Restore original forward methods
#    1066 for module, original_forward in monkey_patched_layers:
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/transformers/models/gemma2/modeling_gemma2.py:457, in Gemma2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, cache_position, **kwargs)
#     454 if output_hidden_states:
#     455     all_hidden_states += (hidden_states,)
# --> 457 layer_outputs = decoder_layer(
#     458     hidden_states,
#     459     position_embeddings=position_embeddings,
#     460     attention_mask=causal_mask_mapping[decoder_layer.attention_type],
#     461     position_ids=position_ids,
#     462     past_key_values=past_key_values,
#     463     output_attentions=output_attentions,
#     464     use_cache=use_cache,
#     465     cache_position=cache_position,
#     466     **kwargs,
#     467 )
#     469 hidden_states = layer_outputs[0]
#     471 if output_attentions:
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/transformers/models/gemma2/modeling_gemma2.py:271, in Gemma2DecoderLayer.forward(self, hidden_states, position_embeddings, attention_mask, position_ids, past_key_values, output_attentions, use_cache, cache_position, **kwargs)
#     256 @deprecate_kwarg("past_key_value", new_name="past_key_values", version="4.58")
#     257 def forward(
#     258     self,
#    (...)    267     **kwargs,
#     268 ) -> tuple[torch.FloatTensor, Optional[tuple[torch.FloatTensor, torch.FloatTensor]]]:
#     269     residual = hidden_states
# --> 271     hidden_states = self.input_layernorm(hidden_states)
#     273     # Self Attention
#     274     hidden_states, self_attn_weights = self.self_attn(
#     275         hidden_states=hidden_states,
#     276         position_embeddings=position_embeddings,
#    (...)    283         **kwargs,
#     284     )
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/transformers/models/gemma2/modeling_gemma2.py:60, in Gemma2RMSNorm.forward(self, x)
#      59 def forward(self, x):
# ---> 60     output = self._norm(x.float())
#      61     # Llama does x.to(float16) * w whilst Gemma2 is (x * w).to(float16)
#      62     # See https://github.com/huggingface/transformers/pull/29402
#      63     output = output * (1.0 + self.weight.float())
#
# File ~/miniconda3/envs/dual/lib/python3.11/site-packages/transformers/models/gemma2/modeling_gemma2.py:57, in Gemma2RMSNorm._norm(self, x)
#      56 def _norm(self, x):
# ---> 57     return x * torch.rsqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)
#
# KeyboardInterrupt:
