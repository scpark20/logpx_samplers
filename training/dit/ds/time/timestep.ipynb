# %%
import torch
data = torch.load('/dataset/dit/train1.5_1k_traj/0.pt')
data.keys()
# Out:
# dict_keys(['cond', 'sample', 'noise', 'traj', 'timesteps'])

# %%
data['traj'].shape
# Out:
# torch.Size([201, 4, 32, 32])

# %%
torch.linspace(1, 1e-3, 200)
# Out:
# tensor([1.0000, 0.9950, 0.9900, 0.9849, 0.9799, 0.9749, 0.9699, 0.9649, 0.9598,
#         0.9548, 0.9498, 0.9448, 0.9398, 0.9347, 0.9297, 0.9247, 0.9197, 0.9147,
#         0.9096, 0.9046, 0.8996, 0.8946, 0.8896, 0.8845, 0.8795, 0.8745, 0.8695,
#         0.8645, 0.8594, 0.8544, 0.8494, 0.8444, 0.8394, 0.8343, 0.8293, 0.8243,
#         0.8193, 0.8143, 0.8092, 0.8042, 0.7992, 0.7942, 0.7892, 0.7841, 0.7791,
#         0.7741, 0.7691, 0.7641, 0.7590, 0.7540, 0.7490, 0.7440, 0.7390, 0.7339,
#         0.7289, 0.7239, 0.7189, 0.7139, 0.7088, 0.7038, 0.6988, 0.6938, 0.6888,
#         0.6837, 0.6787, 0.6737, 0.6687, 0.6637, 0.6586, 0.6536, 0.6486, 0.6436,
#         0.6386, 0.6335, 0.6285, 0.6235, 0.6185, 0.6135, 0.6084, 0.6034, 0.5984,
#         0.5934, 0.5884, 0.5833, 0.5783, 0.5733, 0.5683, 0.5633, 0.5582, 0.5532,
#         0.5482, 0.5432, 0.5382, 0.5331, 0.5281, 0.5231, 0.5181, 0.5131, 0.5080,
#         0.5030, 0.4980, 0.4930, 0.4879, 0.4829, 0.4779, 0.4729, 0.4679, 0.4628,
# ...
