# %%
import torch
data = torch.load('/dataset/sana/train4.5_1k_traj/0.pt')
data['cond']
# Out:
# 'There are many birds flying near the boat. '

# %%
import numpy as np
np.random.randint(1000)
# Out:
# 933

# %%
data['timesteps'].shape
# Out:
# torch.Size([201])

# %%
data['sample'].shape
# Out:
# torch.Size([4, 32, 32])
