# %%
import os 
os.chdir('../../../')
os.environ["DPM_TQDM"] = "False"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# !nvidia-smi
# Out:
# Fri Aug 22 19:41:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.76.05              Driver Version: 580.76.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off |   00000000:19:00.0 Off |                  Off |
# |  0%   59C    P8             39W /  450W |      39MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from utils.clip import CLIPEmbedder
device = 'cuda:0'
clip = CLIPEmbedder(device=device)
print('done')
# Out:
# done

# %%
import torch
torch.log(1/clip.model.logit_scale)
# Out:
# tensor(-1.5234, device='cuda:0', dtype=torch.bfloat16)
