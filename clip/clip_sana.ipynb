# %%
import os
os.chdir('../')

# %%
import torch

data = torch.load(pt_files[0])
data.keys()
# Out:
# dict_keys(['cond', 'raw'])

# %%
from utils.clip import CLIPEmbedder
device = 'cuda:0'
model_names = ['ViT-B/32', 'ViT-B/16', 'ViT-L/14', 'ViT-L/14@336px']
clips = []
for model_name in model_names:
    clip = CLIPEmbedder(model_name=model_name, device=device)
    clips.append(clip)

print('done')
# Out:
#  19%|███████▎                              | 65.0M/338M [00:10<00:44, 6.38MiB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 6
#       4 clips = []
#       5 for model_name in model_names:
# ----> 6     clip = CLIPEmbedder(model_name=model_name, device=device)
#       7     clips.append(clip)
#       9 print('done')
#
# File ~/logpx_samplers/utils/clip.py:11, in CLIPEmbedder.__init__(self, model_name, net_dtype, l2_normalize, device)
#       9 super().__init__()
#      10 self.device = torch.device(device or ("cuda" if torch.cuda.is_available() else "cpu"))
# ---> 11 self.model, _ = clip.load(model_name, device=self.device, jit=False)
#      12 self.model.eval().to(dtype=net_dtype)
#      13 for p in self.model.parameters(): p.requires_grad_(False)
#
# ...

# %%
def get_clip_score(pt_dir, clip):
    pt_files = [os.path.join(pt_dir, f) for f in os.listdir(pt_dir)]
    for pt_file in pt_files:
        data = torch.load(pt_file)
        clip_score = 1 - clip.get_cossim_loss(data['raw'], data['cond'], clamp_mode='hard', reduction='none').detach().cpu()
