# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# Out:
# --2025-09-01 00:34:54--  http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.226.41, 52.216.33.225, 52.217.86.220, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.226.41|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252872794 (241M) [application/zip]
# Saving to: ‘annotations_trainval2014.zip’
#
# annotations_trainva 100%[===================>] 241.16M  5.25MB/s    in 40s
#
# 2025-09-01 00:35:35 (5.98 MB/s) - ‘annotations_trainval2014.zip’ saved [252872794/252872794]

# %%
# !unzip annotations_trainval2014.zip
# Out:
# Archive:  annotations_trainval2014.zip
#   inflating: annotations/instances_train2014.json
#   inflating: annotations/instances_val2014.json
#   inflating: annotations/person_keypoints_train2014.json
#   inflating: annotations/person_keypoints_val2014.json
#   inflating: annotations/captions_train2014.json
#   inflating: annotations/captions_val2014.json

# %%
import json, random
import numpy as np

def load_and_shuffle_coco_captions(path, seed=42, size=50000):
    with open(path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    prompts = [(int(ann['image_id']), ann['caption']) for ann in data['annotations']]
    random.seed(seed)
    random.shuffle(prompts)
    return prompts[:size]

subset = load_and_shuffle_coco_captions('annotations/captions_train2014.json', size=50000)
np.savez_compressed('mscoco2014_train.npz', subset)
subset = load_and_shuffle_coco_captions('annotations/captions_val2014.json', size=10000)
np.savez_compressed('mscoco2014_valid.npz', subset)

# %%
np.load('mscoco2014_val.npz')['arr_0'].tolist()
# Out:
# [['234124', 'A cat laying in a shoe on the ground.'],
#  ['96207', 'A photo taken in a mirror showing the side of a truck.'],
#  ['575355', 'A chair and a table in a small room.'],
#  ['455624', 'a close up of a person driving a motorcycle on a road'],
#  ['453162',
#   'A woman standing in front of a wall with graffiti holding an umbrella.'],
#  ['428830', 'a skater doing a gnarly front side indy in a pool'],
#  ['45075', 'A couple of street signs sitting next to tall buildings.'],
#  ['44800', 'Makeshift skate park set up on a blocked off city street'],
#  ['254824', 'a five story red brick building with a large clock'],
#  ['31717', 'A woman in a bodysuit holding a surfboard posing for a picture.'],
#  ['509786', 'A man in his back swing to serve a ball at a tennis match.'],
#  ['442084', 'a person is catching a wave on a surf board'],
#  ['525705',
#   'A view of a baseball player up to bat and a catcher at a baseball game.'],
#  ['530624', 'A brown dog on a bed sitting under the covers. '],
#  ['331250',
#   'Three guys stand with their skateboards and there is a logo at the bottom.'],
#  ['307943', 'A man in black shirt doing a trick on a skateboard.'],
#  ['269873', 'A multitude of people cross the street in front of streetcar.'],
#  ['405365', 'a number of people riding skis on a snowy slope'],
#  ['340305',
#   'Two elephants with their trunks tied together with a third elephant in the background.'],
#  ['64516', 'A table with several pocket watches on it.'],
#  ['362831', 'Some fried chicken that is on top of a cake.'],
#  ['278121', 'two monitors and keyboard sitting next to a big window'],
#  ['269037', 'Surfers ride waves in a wave simulation machine. '],
#  ['360611', 'a small aircraft , truck, and people standing on the runway'],
#  ['364580', 'a white chair a table a gray couch and two lights'],
#  ['454562', 'A batter is taking his best swing during the baseball game. '],
#  ['469713', 'The two  giraffes are standing close together.'],
#  ['35049', 'A minor league base ball teams awaits their turn up for bat'],
#  ['39512', 'Two men are playing a game with remotes.'],
#  ['185305', 'A guy on a skate board high in the air.'],
#  ['333436', 'a woman walking past a sign while talking on a cell phone \n'],
#  ['308487', 'A group of people standing at a table with bottles of wine.'],
#  ['470032', 'White cockatoo hanging upside down on outside telephone wires.'],
#  ['468022', 'A partially eat cake on a tray being held by a person.'],
#  ['70896', '3 surf boarders enjoying themselves in the ocean.'],
#  ['236161', 'a public transit bus on a road near a building'],
#  ['273708',
#   'Older woman holding out her hands preparing to catch a frisbee. '],
#  ['286544', 'A man pushing a wheelchair on the street.'],
#  ['345139',
#   'The man in the large hat is drinking near many glasses of dark beer.'],
#  ['42888', 'A corner street sign with a tow sign and a art piece'],
#  ['463498', 'A couch and some chairs in a room.'],
#  ['423116', 'A kitchen counter with ingredients spread over it'],
#  ['505520', 'a big lake with some boats out in it'],
#  ['117396', 'A portable bathroom has a gray plastic urinal.'],
#  ['114458', 'Little girl laying in bed snuggling with her blankets'],
#  ['332300', 'A large bell hangs over a clock on the side of a stone wall.'],
#  ['533485', 'some flowers are in a white pot outside'],
#  ['526126', 'A young skateboarder attempts to complete a trick.'],
#  ['423742', 'a cat laying on a desk behind a laptop'],
#  ['358048', 'A giraffe and a boar standing at the side of a pond.'],
#  ['436492', 'A sign explain the meaning of the road work.'],
#  ['189452', 'A group of people and motorcycles with bananas on the side.'],
#  ['101473', 'Two cellphones that are sitting on a desk.'],
#  ['318585', 'Three travellers are brushing their teeth as one is stretching.'],
#  ['422536', 'young woman looking up into a palm tree'],
#  ['182423', 'A black traffic light on a white street post'],
#  ['332025', 'a person holding onto a dog leash while standing on the snow '],
#  ['500723', 'The cake is laying down on a chair that toppled over.'],
#  ['575198', 'A jumbo jet being serviced at an airport.'],
#  ['356427', 'A man stands at a train station with lots of luggage'],
#  ['527529', 'A white cat digging in a book bag.'],
#  ['437651',
#   'A group of women stand in front of a table covered in small plastic cups.'],
#  ['531995', 'A cat with its head in a boot.'],
#  ['203085', 'Man toilet seat while playing a game on computer.'],
#  ['174633', 'An adult and a child walk through the snow on skis.'],
#  ['469634', 'A man riding a skateboard in the middle of the street'],
#  ['190680', 'A tree-lined street  with large yellow traffic signs.'],
#  ['362352', 'A man hanging on to the outside of a train engine car.'],
#  ['446352', 'A little cat sits on a laptop keyboard. '],
#  ['27440', 'A giraffe standing in a small piece of shade.'],
#  ['172924', 'A long white bus is heading through the station.'],
#  ['60069', 'a guy on a surfboard with a kite attached to it.'],
#  ['298691', 'A pan that has some meat and vegetables in it.'],
#  ['261062', 'A room with wooden cabinets and a brown couch.'],
#  ['236730', 'The head and shoulders of a zebra in silhouette. '],
#  ['419971', 'An empty restroom with two urinals and a sink. '],
#  ['24061', 'A picture of a bathroom with a sink and tolet.'],
#  ['542803', 'The city bus in en route to Graham Street. '],
#  ['194297',
#   'A narrow toilet stall with toilet, handicap rails and a bare light bulb.'],
#  ['292908', 'A person on a surfboard riding a wave in the ocean.'],
#  ['209015', 'A giraffe sticking its head into a sunroof of car.'],
#  ['118343', 'some people and a male in a white jacket and his cellphone'],
#  ['173183',
#   'Street signs, corner of Lynn and Bigelow.taken 11.01.2009 23:58.'],
#  ['84258', 'A man wearing a red tie with his left ear pierced.'],
#  ['36277',
#   'A drawer of a chest is open and some files are seen in it and a dog is entering it.'],
#  ['250167', 'A man smiles while holding up a white surfboard.'],
#  ['39081', 'a single person walking the beach with a dog '],
#  ['519399', 'A young man with his board in hand, is observing the waves. '],
#  ['184590', 'Multiple types of vegetables sitting in a card board box.'],
#  ['38701', 'A large golden cake is on a cooling rack.'],
#  ['405195', 'A display of a variety of donuts at a store. '],
#  ['487428', 'a public transit bus driving on a road '],
#  ['503951', 'two canaries perched on a metal rail outdoors.'],
#  ['555005', 'A large dogs comfortably sleeping on someones bed'],
#  ['412757', 'Two green buses are parked on the street by a sidewalk.'],
#  ['70240', 'a lady standing in front of potted plants.'],
#  ['157928', 'A MAN IS PACKING UP SKIES ON THE SNOW LAND'],
#  ['88652', 'A stop sign mounted on a wooden pole that has been defaced'],
#  ['210782', 'A patio with trash cans attached to the fence.'],
#  ['131627', 'A sign is shown that reads Fashion District.'],
#  ['564612', 'A woman posing for a picture in front of some food.'],
#  ['564289', 'A person on a snowboard going down a slope.'],
#  ['188447', 'THERE IS A VEGAN PIZZA ON THE TABLE '],
#  ['335578', 'A woman prepares to hit a tennis ball.'],
#  ['214391', 'A table topped with two sandwiches and bottles of beer.'],
#  ['354369', 'A book sitting on top of a wooden table.'],
#  ['125547', 'This is one of those speedy commuter trains.'],
#  ['438738', 'An adult and child feeding an elephant in a contained area.  '],
#  ['113975', 'A woman in grey shirt with dog jumping for frisbee.'],
#  ['238292',
#   'An exotic bird with a piece of fruit in its mouth from he tree it is perched in.'],
#  ['257359', 'A train is parked at a train station.'],
#  ['514173', 'Four red horses with a man on the farthest one.'],
#  ['192520', 'A picture of a car parked on the side of a road.'],
#  ['38875', 'A living room with a small television and a fireplace.'],
#  ['376278', 'A lazy zebra lays in the straw near a rocky field.'],
#  ['580029', 'Streetlight and number sign on pole above city and hills.'],
#  ['456146',
#   'A group of sheep walking down a path with a few stopping to eat grass along the side.'],
#  ['363594', 'Three men having a discussion in an office.'],
#  ['484584', 'A man holding a tennis racquet on a tennis court.'],
#  ['426972',
#   'A bed in a room with wooden floor and not much else in the room.'],
#  ['528862',
#   'A group of giraffes wonder around in a fenced off area with other animals. '],
#  ['295016', 'A kitten sitting inside of a coffee cup.'],
#  ['226220', 'A cat is sleeping on the arm of a couch.'],
#  ['521995', 'A laptop on a desk in a room.'],
#  ['62311', 'Television monitor in room with many items displayed.'],
#  ['374218', 'A plate full of mixed and cooked vegetables'],
#  ['409052', 'The airplane is sitting and waiting for the passengers.'],
#  ['81210', 'A couple of people on a street under a umbrella.'],
#  ['375469', 'Two individuals catching a wave surfing in the ocean.'],
#  ['65350',
#   'Two young people are skateboarding on the ramp, trying to pull off tricks.'],
#  ['198841', 'a small plant is sitting in a vase'],
#  ['497139', 'Cows grazing on hay in an outdoor pen.'],
#  ['384808', 'A bathroom sink sitting under a bathroom mirror.'],
#  ['328940', 'A dog that is laying between two people.'],
#  ['548336', 'THIS IS A PHOTO OF TWO HAPPY CHILDREN SITTING AT THE TABLE'],
#  ['546556', 'a few goats in a big grassy field out doors'],
#  ['402283',
#   'People watching a player at the plate during a little league game.'],
#  ['515577', 'Two people on skis going down a small hill.'],
#  ['362352', 'An engineer is climbing into the engine compartment.'],
#  ['560993', 'A man stands in front of a small TV holding a Wii controller.'],
#  ['308466',
#   'A bathroom containing a toilet, sink and bathtub with shower, with no accessories.'],
#  ['443605', 'a couple of doughnuts that are in a bag'],
#  ['404607', 'people playing a sport on a dirt field.'],
#  ['421822', 'A couple of giraffes are standing in an enclosure.'],
#  ['579402', 'A couple of zebras standing together in the dirt.'],
#  ['230240', 'Two men who are standing on skis in the snow'],
#  ['532833', 'A photo of a clock with a partly cloudy sky in the background.'],
#  ['192529', 'Park bench falling apart next to a bus stop sign. '],
#  ['292365', 'A cat with paws on the toilet seat intrigued'],
#  ['181739', 'a grey cat sitting next to a computer monitor '],
#  ['513507',
#   'Many speedboats are travelling through the water near sailboats.'],
#  ['411821', 'four different suitcases red blue brown and black colors'],
#  ['143974', 'A boat is traveling down a river with a cow crossing the water.'],
#  ['532983', 'People are at dining tables on a train.'],
#  ['191613', 'some buildings and a red double decker bus and two people'],
#  ['231028', 'Three men skiing down a mountain on a sunny day.'],
#  ['390954',
#   'A delicious looking slice of red velvet cake with chocolate frosting.'],
#  ['43165', 'A zebra standing right behind another in the hay'],
#  ['272241', 'A black cat sits on top of a red motor bike.  '],
#  ['99242', 'A man skiing down a snowy hill alone.'],
#  ['376939', 'A young boy who is surfing on a surfboard.'],
#  ['300403',
#   'Round table of women at a restaurant while one woman is on the phone.'],
#  ['448319', 'Three zebras in the ground eating dry grass.'],
#  ['383175', 'A train that is sitting on a train track.'],
#  ['442175', 'Old, tusked elephant eating grass with his buddies'],
#  ['560797', 'A group of men on a field playing baseball.'],
#  ['471335', 'A bulldog staring at a woman as she walks by.'],
#  ['261999', 'a guy and girl kissing while standing by a bike'],
#  ['365663',
#   'A man in a blue and white check shirt doing tricks on a skateboard. '],
#  ['469061', 'A young boy and woman are skiing in the snow.'],
#  ['464296', 'A wreath with a red bow on it hanging on a white door.'],
#  ['57433', 'a group of people in black clothes holding onto small umbrellas '],
#  ['89790', 'a man is standing next to a green truck'],
#  ['221829', 'A small bowl of bread pudding served on a plate'],
#  ['98268', 'An old, weathered street sign that says One Way'],
#  ['503183',
#   'A brown-haired female doll is suspended between two parking meters.'],
#  ['410437', 'A snow covered city street featuring a red fire hydrant'],
#  ['367900', 'A shiny blue and yellow passenger train at a station.'],
#  ['480015', 'A computer desk topped with a computer and a keyboard.'],
#  ['496722', 'A post office box is on the side of a busy street.'],
#  ['313647', 'A batter reaches very low to bat at a ball at knee height.'],
#  ['386962', 'A pair of yellow high heels sits in front of an open suitcase.'],
#  ['319345', 'A line of motorcycles parked next to parking meters.'],
#  ['19142', 'A statue on top of a giant clock tower near a flag.'],
#  ['204435', 'A warning sign about the danger of a checkpoint arm.'],
#  ['58304', 'A city link red bus picking someone up.'],
#  ['520237',
#   'A woman arranges an umbrella while another woman looks on amused.'],
#  ['333826', 'A red fire hydrant surrounded by yellow pillars'],
#  ['326248',
#   'A referee and tennis player speaking while fans watch in the stands.'],
#  ['253362', "A hand is reaching out to a brown and white cow's nose."],
#  ['439770', 'The empty surf board is floating on top of a wave.'],
#  ['271852', 'A baseball batter up at the plate that just hit a ball '],
#  ['67156', 'A man in grey shirt brushing his teeth and holding a camera.'],
#  ['61171', 'A herd of black and white cows eating dry grass.'],
#  ['137402', 'A bathroom is shown with a mirror, sink, and shower.'],
#  ['487931', 'The young soccer players are enjoying their intense game.'],
#  ['246057', 'A rescue truck makes a turn on a city street.'],
#  ['34582',
#   'A plate filled with cake next to doughnut holes and other treats.'],
#  ['240049', 'A woman holding a young child in her arms.'],
#  ['490939', 'Two men with glasses sitting at a table using laptops'],
#  ['466425', 'The hotdogs are on the plate with corn on the cob.'],
#  ['479011', 'A plate full of food, including meat, potatoes, and a muffin'],
#  ['551288', 'Woman sitting at a dinner table with multiple plates of food. '],
#  ['268882', 'a couple flying a rainbow kite in the sky'],
#  ['378709',
#   'A bathroom with a white toilet sitting under a bright white light.'],
#  ['488755', 'Two skiers trekking across the terrain in the snow'],
#  ['14450', 'A single train car passing tracks on a hill.'],
#  ['29056',
#   'a closeup of a street sign for "Main Street" with a sign for the Wisconsin State Fair'],
#  ['49885', 'Modern medical ambulance bus parked on a sunny day'],
#  ['282150', 'A blue motorcycle is parked on the side of a street.'],
#  ['15908', 'a kid is riding a skateboard on a ramp'],
#  ['508370', 'A couple of men as one points to the right next to a bicycle.'],
#  ['173400', 'A man is sitting on a bed with brown headboard.'],
#  ['484075', 'Small computer station holding a white computer. '],
#  ['503841', 'Green stop lights are set against a tall building.'],
#  ['221433', 'A guy doing a trick on a surf board.'],
#  ['354868', 'A train sitting on the track at the station.'],
#  ['12817', 'A man on a skateboard performing a trick.'],
#  ['294437', 'A laptop laying on a table near a tv.'],
#  ['519338', 'Rusty train sitting on train tracks in high grass. '],
#  ['494863', 'A train on the train tracks in the daytime.'],
#  ['451214', 'A man putting salt on a pizza at a restaurant, '],
#  ['392183', 'A woman that is holding a cellphone under an umbrella.'],
#  ['325357',
#   'A large silver pot sitting on a counter next to a red brick wall.'],
#  ['201887', 'An old Volkswagen bus parked next to the curb.'],
#  ['510358', 'A large bus parked on the side of the street.'],
#  ['457226',
#   'Many bags are lumped together on the floor, including a shopping bag, a duffel bag and a black suitcase.'],
#  ['93360', 'a dog jumping up to catch a frisbee in the air '],
#  ['42507', 'A couple of small children standing on top of a sandy beach.'],
#  ['389400', 'A herd of cattle walking across a muddy field.'],
#  ['446285', 'Man on skateboard concentrating while going down a pipe.'],
#  ['463388', 'Nine children and one adult on a tennis court'],
#  ['95113', 'A man standing on a pair of skis wearing a black jacket'],
#  ['521405', 'A tooth brush sits next to a toy.'],
#  ['548921', 'A cow reaching around to lick itself in a field'],
#  ['316138', 'A man standing in the middle of several parked motorcycles.'],
#  ['102400', 'A brightly colored red and green bus is parked.'],
#  ['338552', 'two snow boarders racing down a snowy slope '],
#  ['419860', 'A pizza and a person with a pizza cutter on a blue table.'],
#  ['476910', 'A teddy bear sitting in a bunch of bananas on a banana tree.'],
#  ['475108', "A black, white and orange cat yawning and shedding it's fur. "],
#  ['567922', 'A bluish train car pulls into a station.'],
#  ['541071', 'A man flying a red kite in a blue sky.'],
#  ['137842', 'Two zebras are standing in the road near a grassy field.'],
#  ['293733', 'A person is taken in this very picture.\n'],
#  ['531000', 'A giraffe licking a board on a  fence.'],
#  ['224819', 'A sandwich of some kind on a plate.'],
#  ['153971', 'A kid tossing a blue frisbee towards another kid.'],
#  ['219201', 'A person that is playing with a tennis ball.'],
#  ['89430', 'A cat on a seat resting and with its eyes closed.'],
#  ['176381', 'A person that is riding a surfboard under a wave. '],
#  ['21046', 'A bathroom area with toilet and tools on it.'],
#  ['361386', 'A motorcycle is in a parking lot with a helmet on top.'],
#  ['16164', 'Black and white dog laying in dirty public restroom.'],
#  ['43947', 'A close up of a street pole with no parking signs.'],
#  ['36124', 'A cat laying on the pavement in front of a house.  '],
#  ['199127', 'an image of a bus that is driving down the street'],
#  ['439525', 'A man and a woman cutting into a cake with a knife.'],
#  ['241620', 'Two surf boards have been placed in a rack, ready to be used.'],
#  ['115182', 'Three zebras walking in a dusty field of dirt.'],
#  ['319706', 'A cat sits on a desk in front of a computer. '],
#  ['78892', 'A passenger train that is going over a bridge.'],
#  ['560918', 'Small child holding a skateboard while hunched over.'],
#  ['129897', 'A group of men sitting at a table in a cafe.'],
#  ['207003', 'people on a hill flying two large kites in the sky'],
#  ['109265', 'An elephant walking through a grassy part of the river'],
#  ['474402', 'A sepia photo of Big Ben in London, seen from below.'],
#  ['47394', 'A baseball player takes a big swing at the ball'],
#  ['531854', 'Two ducks are swimming outdoors in the water. '],
#  ['111416', 'Three boys walking along the beach with surf boards.'],
#  ['286813', 'A woman riding a carriage pulled by a brown pony in a race. '],
#  ['361721', 'A street scene with a man driving a blue truck.'],
#  ['313182', 'A purple bus with a person on the side driving around a curb.'],
#  ['318596', 'there are two street signs on the same pole'],
#  ['378709', 'A bathroom with a toilet and sink and some wood cabinets.'],
#  ['294370', 'Road signs giving directions and lights next to a building'],
#  ['258954', 'a woman poses next to a fridge '],
#  ['73830', 'A herd of giraffe standing next to each other on a  field.'],
#  ['489739', 'A little girl is sitting in an IKEA kart enjoying a snack. '],
#  ['277032', 'A man standing next to backpacks and skis and poles.'],
#  ['244019', 'A fire hydrant painted red white and blue'],
#  ['382111',
#   'two young men on horseback at a gas station near some gas pumps and trucks'],
#  ['91105',
#   'Two young boys in vests sitting on the grass, with one boy holding a football in his lap.'],
#  ['313399', 'A hot dog sitting on top of a wrapper next to a receipt.'],
#  ['503051', 'A lady is pulling her luggage through a terminal.'],
#  ['11305',
#   'a living room with a couch and two low wooden tables with floor cushions in a log cabin.'],
#  ['85144', 'Two people with backpacks skiing on snow covered slopes.'],
#  ['397475',
#   'two people in a field playing frisbee with trees in the background'],
#  ['505822', 'A flower arrangement on a table with back lighting.'],
#  ['46048', 'Playing board games while the iron heats up in the bedroom.'],
#  ['168129', 'An elephant walks through the tall grass in the sun.'],
#  ['569722', 'A plate with vegetables and meat on a table.'],
#  ['4754', 'The zebras are beginning to head towards their water source.'],
#  ['416059', 'Two people walk through the snow behind a dog.'],
#  ['449895', 'A man fixing a traffic light while on a cherry picker.'],
#  ['92656', 'A person is wind sailing in the ocean.'],
#  ['60464',
#   'Individual bowls of fish, vegetables, rice on a table in an Asian restaurant.'],
#  ['242270',
#   'A red metro bus stopped beside a sidewalk in the city as traffic passes.'],
#  ['188718', 'A couple of zebra standing on top of a dry grass field.'],
#  ['45594', 'a truck with a lift on it passing two cars'],
#  ['562155', 'a person wearing glasses and a tie in a car'],
#  ['74132', 'An empty bathroom has a tub and a sink in the background'],
#  ['552510',
#   'Kids in green and white soccer outfits are on a field as other kids wear a yellow vest over their uniform.'],
#  ['427796', 'A metal kitchen table with a shelf holding knives.'],
#  ['542856', 'A city bus carrying ads featuring women coming to town.'],
#  ['417957', 'a bench sitting in a grassy field with trees in the background'],
#  ['74001', 'a small dog is being pet in the house '],
#  ['194595', 'Scissors with a blue handle are in a plastic package. '],
#  ['322031', 'Elephant and it trainer stand in front of a crowd of people. '],
#  ['285992', 'a bird is perched high up in a tree'],
#  ['145742',
#   'A photo of chalk writing on the sidewalk next to a white fire hydrant.'],
#  ['118544', 'A man on a laptop at a desk in a contest ad.'],
#  ['526955', 'a young girl eating something while playing in the woods '],
#  ['147545', 'A kitchen with and island and several counters in it.'],
#  ['21470', 'A baseball player is waiting his turn to catch the ball.'],
#  ['241068', 'Black and white photograph of three beds and two nightstands.'],
#  ['503585',
#   'A man with a brown bag and blue jacket stands by a train that is moving.'],
#  ['271248', 'Bus backing up and being loaded onto a truck outside'],
#  ['25747', 'Short traing coming down the tacks in the middle of the woods.'],
#  ['48972', 'Sidewalk area of city with parked motorcycles and truck nearby.'],
#  ['46031', 'A laptop screen displays an image of bright green leaves.'],
#  ['462330', 'A DOG IS LYING ON HIS BACK PAWS UP'],
#  ['385535', 'A sign at a traffic light that says "US-1 Whitehead St." '],
#  ['140974',
#   'Two street signs are displayed with the branches of a tree in the background.'],
#  ['69356', 'a bunch of food is on sale at a market'],
#  ['186182', 'Glasses sitting on top of a stainless steel refrigerator. '],
#  ['528980', 'a red umbrella is inside out in a city'],
#  ['318730', 'A pair of spotted scissors cuts a striped ribbon. '],
#  ['395382', 'Two young children laughing as they play on a fire hydrant.'],
#  ['544351',
#   'A female tennis player standing at the baseline of the tennis court and holding her racquet with two hands.'],
#  ['158945', 'Seats placed on top of an elephant that is standing outside. '],
#  ['90108', 'A white bathroom sink sitting under a bathroom window.'],
#  ['226380', 'A women who is holding a red umbrella in the rain.'],
#  ['543402', 'this is a computer chair with an umbrella '],
#  ['355228', 'A small white mouse sleeping on top of a remote control.'],
#  ['33731', 'A skateboarder ollies over a boulder at night'],
#  ['351621',
#   'A shark design and a car design kite being flown in the blue sky.'],
#  ['204640', 'Two bears grasping onto each other in a zoo enclosure.'],
#  ['307668', 'A dog is looking out the window of a car.'],
#  ['511463', 'A woman walking a dog through the woods.'],
#  ['335844', 'A toaster oven with an item baking inside of it.'],
#  ['388581', 'a public bathroom with a toilet and hand rail'],
#  ['34657', 'A group of guys on a couch watching tv'],
#  ['130599', "A man punching an innocent giraffe in the side of it's head."],
#  ['434459', 'Two people are cutting into a large cake.'],
#  ['323729',
#   'a wood floored living room with a modern couch and large windows'],
#  ['200770', 'A man with hat running after a frisbee on the field'],
#  ['395644', 'Five cats are sleeping on a bed with a red bedspread.'],
#  ['98674', 'A bird is standing on the small branch outside. '],
#  ['161605', 'A sandwich on a black plastic plate with a pickle.'],
#  ['308156', 'A room with two chairs and a couch in it.'],
#  ['15687', 'A man holding a tennis racquet as a tennis ball approaches him.'],
#  ['464649', 'THIS IS A PICTURE OF A BUNCH OF FRESH GREENS ON DISPLAY'],
#  ['534817', 'A boy is watching a bird by the shoreline.'],
#  ['241832', 'A close up of wine glasses filled with red wine. '],
#  ['472621', 'An old fashion above ground tub is shown with gold feet.'],
#  ['334075', 'A baseball game in progress with the batter up.'],
#  ['96001', 'A table topped with a book, umbrella and other items.'],
#  ['516022', 'A group of elephants standing near the water'],
#  ['240817', "A person that is on ski's standing in the snow."],
#  ['424585', 'the truck has a barrel in the back of it'],
#  ['506561',
#   'two men and a woman on a tennis court with a man holding a tennis racket'],
#  ['575012', 'black woman sits on fire hydrant talks on phone'],
#  ['231512', 'a large light tower with a clock built into the side of it'],
#  ['310902', 'The train is traveling over the curved bridge.'],
#  ['95039', 'Players at home plate during major baseball game.'],
#  ['145751', 'A nice dressed man with his arms crossed smiling.'],
#  ['464911', 'A picture of a barbeque sandwich with lettuce on a bun. '],
#  ['153184', 'Three birds sit on the back of a giraffe. '],
#  ['513615', 'a fighter jet flies by a mountain '],
#  ['54628', 'A wedding cake with flowers in a banquet hall.'],
#  ['565245', 'a processing machine with a bunch of doughnuts on it '],
#  ['577959', 'A person flying a kite in sandy, watery area.'],
#  ['267314', 'A girl sits with her back to a suitcase.'],
#  ['468917', 'A woman sitting at a table with a pink and white cake.'],
#  ['187852',
#   'A bunch of people gather with cameras an video recorders. The man is taking a picture with his phone.'],
#  ['530652', 'A man wearing a bandana is flying a kite.'],
#  ['165681', 'a huge group of motor cycles sitting on the street'],
#  ['32193', 'Three giraffe and two zebras are grazing in the grass together.'],
#  ['299986', 'A man sitting on a bench listening to headphones.'],
#  ['481480', 'Horses and jockeys running on a racing track.'],
#  ['156637', 'A glazed donut sitting next to a knife. '],
#  ['67948', 'A red train engine coming into a station.'],
#  ['474410', 'A fleet of air crafts are flying formation.'],
#  ['507684', 'A tower that has a clock on it.'],
#  ['96034',
#   'A large brown Teddy Bear stands sideways in front of a yellow road map.'],
#  ['577403', 'A couple of young boys with skateboards pass a city bus'],
#  ['405223',
#   'An man playing tennis about to hit a ball that is coming toward him.'],
#  ['474667', 'a person is holding up a black cat'],
#  ['537889', 'an image of billboard that is on the repair'],
#  ['500940', 'a sailboat sails with its sails full in front of a city'],
#  ['527497', 'a couple of monitors are on a desk'],
#  ['569758', 'A child pitcher gets ready to throw the baseball'],
#  ['198271', 'large brick tower with a clock the front'],
#  ['318908', 'A small dog with orange hair sitting on top of a desk.'],
#  ['133750', 'A zebra is standing next to a log'],
#  ['176275',
#   'A clean bathroom is pleasantly decorated with wallpaper and decorations.'],
#  ['154090', 'A woman is playing tennis on a brown dirt court.'],
#  ['316666', 'this is a restaurant with flowers on the bar'],
#  ['8292', 'A small kitchen with an even smaller fridge.'],
#  ['535933', 'A plate full of pizza with an empty plate beside it.'],
#  ['45550', 'a close up of a person holding up a plate of food'],
#  ['78313', 'Several shelves that have some glassware on them.'],
#  ['558350', "Pet sitting on person's lap in front of a computer. "],
#  ['320832', 'A fork and knife carve into a stack of pancakes.'],
#  ['104585', 'A woman hits a tennis ball at the end of the court.'],
#  ['526892',
#   'A man touching an iron board in a room filled with other items. '],
#  ['464814', 'a living room filled with couches, chairs, tv, and windows'],
#  ['357024', 'A bunch of old school video games sitting  in a play room.'],
#  ['225352',
#   'A laptop is kept on the table.A person is sitting on other table.'],
#  ['412693', 'Two small birds sitting on a piece of wood'],
#  ['463012', 'A small bed with different color pillows on it. '],
#  ['347724', 'A basket full of fresh grown carrots next to other vegetables.'],
#  ['285114', 'very many planes being offloaded at the airport'],
#  ['538394',
#   'A man wearing a trenchcoat and holding a large knife stands against a smoky night background.'],
#  ['273637', 'A woman with a scarf on holding up some wine glasses.'],
#  ['130555', 'The shelves below the kitchen window are filled with objects.'],
#  ['209728', 'an image of birds that are perched on rocks'],
#  ['160761', 'A man looking into a mirror brushing his teeth'],
#  ['70321',
#   'People standing in the street on the other side of a traffic signal.'],
#  ['266601', 'some boys having some food at a table together '],
#  ['534271', 'A few containers sitting on top of a table next to a blue wall.'],
#  ['502698', 'A man wearing a tie is sitting down on the checkered floor'],
#  ['201899', 'A skateboarder uses a parking area as a skate park.'],
#  ['477750', 'a line of men riding elephants through a field'],
#  ['125059', 'A view of a bathroom shows a toilet, sink and mirror.'],
#  ['117988', 'A group of people are standing on the street.'],
#  ['64974', 'a person jumping a skate board in the air'],
#  ['377814', 'Six assorted donuts resting in the box they arrived in.'],
#  ['135900', 'A skillet with two pans containing eggs and ham.'],
#  ['577377', 'A kitchen with brown / red painted cabinets'],
#  ['99081', 'A person trying to get on a train, but the door shut.'],
#  ['140908', 'A couple of stuffed animals sitting on a park bench'],
#  ['498997', 'A man sitting in a chair holding a guitar.'],
#  ['456236', 'A plate filled with steak, potatoes and broccoli.'],
#  ['455229', 'A giraffe in a sandy area next to trees and a rock wall.'],
#  ['489909', 'A basket that is full of fruits and vegetables.'],
#  ['179960', 'A few guys playing beach volleyball in the sand.'],
#  ['471073', 'A few little kids playing a game of baseball.'],
#  ['318426', 'A transit train in front of a multi story brick building.'],
#  ['174042', "The dog has a Frisbee in it's mouth while in the air."],
#  ['567011', 'A man on a surfboard riding a wave. '],
#  ['348795', 'Man sit on a icy bench with skis on his feet.'],
#  ['440959',
#   'A person on a skateboard on a low platform with a ramp, near a graffiti wall.'],
#  ['565296', 'A kitchen area with a counter and refrigerators.'],
#  ['271457', 'The wooden bench has tall grass around it near the water.'],
#  ['486093', 'Three seagulls swimming in the ocean with waves.'],
#  ['554156', 'A tennis player preparing for the incoming ball.'],
#  ['103873', 'a couple of men are standing with a dog'],
#  ['343976',
#   'A city street lit up in a night scene with cars in the background. '],
#  ['453507', 'A cat with a small hat glares at the camera'],
#  ['15810', 'An image of a man is shown through multiple mirrors'],
#  ['437129', 'A skate boarder is doing a trick in an empty pool.'],
#  ['208031', 'this is a horse running in the dirt'],
#  ['182784', 'A brown cow standing next to a store with lots of water.'],
#  ['374083', 'A man and a child in the kitchen with two cakes.'],
#  ['205102', 'A bike is propped up against a fence on a path.'],
#  ['206596', 'A young boy taking a swing at  a ball'],
#  ['63240', 'A man standing on a type of boat during the day.'],
#  ['190585', 'A plate with meat, broccoli, and noodles is sitting on a table.'],
#  ['205251', 'People surf on a man-made surfing spot in the city.'],
#  ['494439', 'A couple of trains traveling down tracks next to each other.'],
#  ['383443', 'Large white bathroom showing sink, tub, TV, and countertops.'],
#  ['572671', 'A little yellow bird eats at the bird feeder most days.'],
#  ['468525', 'An airplane taking off from an airport runway.'],
#  ['491515', 'Multiple pieces of luggage at the bottom of a ladder on a boat'],
#  ['409856', 'Black train arriving down the tracks at its station.'],
#  ['51324', 'A woman talks on her cellphone while riding a city bus.'],
#  ['156370', 'Yellow street sign for bicyclists on a busy city street. '],
#  ['427077', 'A man stands poised with a baseball bat.'],
#  ['253718', 'Broccoli is being prepared in a pan on a stove.'],
#  ['269689', 'A group of men on a field with baseball bats.'],
#  ['556562', 'A close up of doughnuts covered in powdered sugar.'],
#  ['268992', 'a desk that has a lot of mess on it'],
#  ['94405', 'A number of skiers hike down a snow covered mountain.'],
#  ['452966', 'Two men are playing a remote video game.'],
#  ['288493', 'A man and his reflection from a side mirror.'],
#  ['243148', 'A lady seems to be attending to a fallen toddler. '],
#  ['104563', 'A young man riding a skateboard on a patch of grass.'],
#  ['464092', 'A row of red park benches on a brick walkway at a park.'],
#  ['172006', 'There are bunk beds in the childrens room.'],
#  ['385005', 'A view of a side of a room in the daylight.'],
#  ['360595', 'A skateboarder talks with another man at a park.'],
#  ['556518', 'A baseball player in uniform at bat during a day game.'],
#  ['368978', 'A jumbo jet plane in flight with a city in the background.'],
#  ['133034', 'A cell phone on disorganized work space with other things'],
#  ['568337', 'Two small plastic objects resembling a suitcase. '],
#  ['455741',
#   'A man with a frisbee crouches down on a lawn in front of a fence. '],
#  ['250594', 'A skier makes their way down a snowy course'],
#  ['91912', 'an Olympic pool sitting next to a river '],
#  ['1573', 'There is an old stove with old pots on the burners'],
#  ['197462',
#   'An old city fire hydrant has "Love was found here" painted on it. '],
#  ['176362', 'A baseball player taking a swing at a ball'],
#  ['364133',
#   'A set of three pieces of luggage sitting up against a brick wall.'],
#  ['530820', 'A man near a fence holding a racquet.'],
#  ['364157', 'A well lit bedroom with a perfectly made bed.'],
#  ['280733', 'this is a street with a couple busses riding down it'],
#  ['99515', 'Two women and one man are browsing an antique store.'],
#  ['305060', 'a person getting a piece of pizza pie'],
#  ['389109', 'Pizza on a table at an outdoor restaurant at night'],
#  ['541813', 'A couple of small rooms in a house.'],
#  ['491653',
#   'A table with gloves, a cell hone, brush, wallet and lipstick on it. '],
#  ['542549', 'A bed with books and papers and a blanket.'],
#  ['159030', 'A den with a fire place, couches and a table.'],
#  ['311327', 'Four adults and a child ride on a paddle boat.'],
#  ['126833', 'A person is sitting by themselves on a park bench.'],
#  ['353408', 'A few elephants playing around in the muddy water.'],
#  ['198563', 'A cat with crazy eyes standing on a toilet.'],
#  ['315448', 'A person is riding an orange motorcycle doing a hand motion'],
#  ['143479', 'A man is serving grilled hot dogs in buns. '],
#  ['425000', 'women in black coats walk along the sidewalk'],
#  ['203239', 'A man dressed all in black riding a skateboard.'],
#  ['542933', 'A batter is about to bat in the wide open area. '],
#  ['38601', 'A boy riding a skateboard on a skateboard ramp.'],
#  ['209041', 'Guy working on a laptop inside of a library.'],
#  ['136938', 'a tray filled with assorted donuts that are glazed'],
#  ['316658', 'A person sits on a picnic table watching ducks near the lake.'],
#  ['376996',
#   "A plane with it's propellers whirling that is sitting in a field."],
#  ['217951',
#   'a person riding a surf board with a parachute in a body of water'],
#  ['332432', 'A man at the airport trying to claim his luggage.'],
#  ['493799', 'A plate topped with vegetables, meat and fruit.'],
#  ['335532', 'A girl is taking a bite out of a sandwich.'],
#  ['449031', 'A yellow bus on street with a building in the background.'],
#  ['185373', 'a number of motorcycles parked on a side walk '],
#  ['360400', 'a person holding a cell phone in their hand'],
#  ['219524', 'A large black bear moving toward a vehicle.'],
#  ['295336', 'Four giraffes encircle the palm tree within the fence.'],
#  ['37945', 'A little boy holds a toothbrush in the bath.'],
#  ['560880', 'Some horses are being led In a field'],
#  ['251232',
#   'A model train on a model bridge decorated with christmas lights.'],
#  ['525208', 'A freeway is busy in the late evening.'],
#  ['307421', 'A cow standing at a hay feeder in a fenced in field.'],
#  ['473260', 'A collection of stop signs in a lot next to construction cones.'],
#  ['464087',
#   'A baseball batter takes a mighty swing as the catcher and umpire look on.'],
#  ['82180', 'Two stuffed animals in a wooden outdoor chair.'],
#  ['61997', 'a man is standing near a couple of umbrellas'],
#  ['506803', 'a laptop is next to a reader on a desk'],
#  ['566450', 'A white refrigerator freezer sitting inside of a kitchen.'],
#  ['554241', 'A group of people standing on top of a brick covered area.'],
#  ['360342', 'A motorcycle parked along a road in front of a vineyard.'],
#  ['302318',
#   'A woman is walking her baby in a stroller and talking to friends.'],
#  ['14526', 'A trolly or train car in an urban area.'],
#  ['200252',
#   'A pair of green sneakers on a single bed with a nightstand next to it'],
#  ['145742', "A fire hydrant's shadow is shown outlined on the sidewalk."],
#  ['243190',
#   'A carrot salad mixed with other shredded vegetables and raisins.'],
#  ['249273', 'A red fire hydrant on the middle of a sidewalk.'],
#  ['398119',
#   'Two double decker buses are in traffic with people on the sidewalk.'],
#  ['213445', 'a big cat sitting in a little bowl '],
#  ['8351', 'two dogs wearing jackets standing in a yard'],
#  ['326664', 'The skateboarder is attempting a trick on the ramp.'],
#  ['32817', 'Two men working on and repairing a toilet'],
#  ['553436',
#   'Two men are standing in a kitchen and a medium sized dog is looking up at one of them.'],
#  ['40986', 'Assorted items on a counter top in a kitchenette.'],
#  ['477227', 'Several fishing vessels docked at the docks in harbor.'],
#  ['135524', 'a woman holds an umbrella standing in front of a lake '],
#  ['546160',
#   'A woman wearing a black shawl with white umbrellas in the background.'],
#  ['301766', 'A man leaping off the side of a cliff while skiing.'],
#  ['291537', 'A person riding a snowboard down a snowy slope.'],
#  ['133034', 'there are two phones and a watch on the table'],
#  ['7325', 'A person that is taking a picture of a person.'],
#  ['528314', 'A person skiing down a  mountain kicking his leg up.'],
#  ['275279', 'The dual sink counter of the bathroom has a flower vase on it.'],
#  ['255654', 'A toilet stall with green marble walls and a painting.'],
#  ['548780', 'Two women sitting on a bench with one smoking a cigarette.'],
#  ['148358', 'Some very cute zebras in a grassy field.'],
#  ['238602', 'Brown cat with a pink knit had sitting on top of its head. '],
#  ['93604', 'A kitchen with two ovens and a floral rug on the floor. '],
#  ['260883',
#   'A giraffe stands with his head above a tall rock; some green trees are in the background.'],
#  ['310082', 'a sheep is standing on a white fence'],
#  ['524373', 'A giraffe standing next to a palm tree on a field.'],
#  ['414068',
#   'A stem engine train traveling through a lush green country side.'],
#  ['192529', 'A bus stop sign sitting next to a bus stop bench.'],
#  ['433547',
#   'The couple is sitting on the bench at the top of the sunny steps.'],
#  ['241876', 'A cat standing on the toilet bowl seat'],
#  ['95191', 'Three seperate trains stopped on three seperate tracks.'],
#  ['63104', 'A young boy in a baseball hat and glove'],
#  ['147448', 'Five people are sitting together playing a video game.'],
#  ['188546', 'A dog with a birthday hat on his head.'],
#  ['109612', 'THERE IS A BLACK AND WHITE CAT IN THE BACK GROUND'],
#  ['287396', 'A double decker bus displays a sign reading Garage'],
#  ['211186', 'A spacious living room with a large fireplace.'],
#  ['419369', 'Blonde male mid-swing playing tennis in tennis court'],
#  ['60240', 'A person uses their hands to operate a cell phone'],
#  ['505891', 'A brown and white cat laying on a bed.'],
#  ['194425', 'LARGE PIECE OF ART SHOWING SCISSORS OVER PAPER OVER ROCK'],
#  ['29059', 'An adorable little girl holding a sandwich in her hands.'],
#  ['146448', 'A young child is holding a blue skateboard.'],
#  ['145684',
#   'A woman in a blue coat and yellow boots holding an umbrella in the snow. '],
#  ['380011', 'Two horses standing near a fence in the snow.'],
#  ['321314', 'flowers in a vase next to more vases on a table'],
#  ['522727', 'A man poses for a picture in a nice dinner jacket.'],
#  ['458918', 'A tall tower stands in the distance, it has clocks on it.'],
#  ['577847', 'White plate with fruit and pizza sitting on top of it. '],
#  ['172952', 'A man and woman posing together for a picture.'],
#  ['441147', 'A stack of antique luggage is displayed with price tags.'],
#  ['412873', 'A black and white photo of a cow and a sheep .'],
#  ['185479', 'A man who is sitting on the ground working on his laptop.'],
#  ['571821',
#   'A group of three people posing in front of a red double decker bus. '],
#  ['399012', 'Boiled eggs, tea and donuts on a picnic table'],
#  ['434873', 'A picture of a person in the beach.'],
#  ['371058', 'A young man is standing with his long board.'],
#  ['49450', 'A woman hitchhiking while another woman sits on a suitcase'],
#  ['336049', 'People watching a kid skateboard on a half-pipe.'],
#  ['29465', 'A small bird is standing in the snow.'],
#  ['299409', 'A sign saying "END ROAD WORK" is in front of a truck on a road.'],
#  ['501385', 'Three giraffes in a barren fenced in area.'],
#  ['367626', 'Toy helicopter filming a circular in midair after launch Waze'],
#  ['66360',
#   'Usually people use jam for croissants like what we see on the table.'],
#  ['99984', 'A series of road signs near an intersection.'],
#  ['579925',
#   'A man swings his bat as another man behinds him is squatting to catch the ball while people watch.'],
#  ['86650', 'A bedroom desk with a Chicago picture near it.'],
#  ['207844', 'a large beach filled with many people and umbrellas'],
#  ['270571', 'A woman holding a large knife and a piece of food.'],
#  ['535245', 'A cow drinks water in a dirty pond next to a field.'],
#  ['47511',
#   'A woman and an elderly woman sitting at a desk together in a classroom setting with notebooks and pencils on the desk.'],
#  ['482730',
#   'A platter of veggies including, broccoli, carrots, and possibly potatoes.'],
#  ['326312', 'There is a red fire hydrant in the middle of a sidewalk'],
#  ['432373',
#   'A blue street sign in font of hanging yellow peppers and onions. '],
#  ['359851', 'We see two men in character costumes on the sidewalk.'],
#  ['105872',
#   'An older black and white picture of a cue of people boarding a bus'],
#  ['188345', 'The desert is decorated with all the fixings.'],
#  ['437145', 'A toy train runs along an outdoor track.'],
#  ['240418', 'A man on a surfboard surfing on a wave.'],
#  ['533589',
#   'A bright green fridge sits next to a shelf holding various bottles.'],
#  ['260925', 'The cat is laying on the hood of the car. '],
#  ['121152', 'A bus going under a blue steel bridge.'],
#  ['443006', 'A group of zebras walking near a stream'],
#  ['208830', 'A church with a large tower and clock.'],
#  ['251379', 'Old coin operated parking meters with the innards removed'],
#  ['405093', 'A tennis player lunges to hit the ball. '],
#  ['373440', 'Teddy bears are on display beneath a ?travel necessities" sign'],
#  ['112110', 'A man raising a foot over a brief case'],
#  ['375760', 'an open suit case with three purple items of clolthing'],
#  ['171788', 'A man is in action with the ball on a tennis court.'],
#  ['156696', 'a train on train tracks at a train station'],
#  ['449676', 'this is a person flying a kite in the water'],
#  ['94614', 'A man riding skis down the side of a snow covered ski slope.'],
#  ['175437', 'a man is in a store making donuts with flour'],
#  ['134278', 'An elderly man attempts to blow a birthday candle out.'],
#  ['510636', 'A woman that is sitting under an umbrella.'],
#  ['172498', 'A yellow bus is parked outside in the parking lot.'],
#  ['318224', 'An orange hydrant next to a large building'],
#  ['330419', 'there is a zebra that is seen standing next to a tree'],
#  ['71284', 'a large group  of people walking among horses and sheep'],
#  ['189267', 'A soldier in a white arctic uniform on skiis'],
#  ['568560', 'A man who is lifting one leg up on a tennis court.'],
#  ['560361',
#   'People standing on the backs of elephants that are standing in the river.'],
#  ['116845', 'Organic fruits and vegetables on display in containers.'],
#  ['508602', 'a close up of a bird on top of a parked car '],
#  ['423396',
#   'A light illuminating a handsome old clock with carved wooden cherubs'],
#  ['359034', 'A man wearing a beanie and a neck tie.'],
#  ['520427',
#   'Bicycle rider in black and orange outfit standing next to his bicycle. '],
#  ['3466', 'a photo of a person wearing pants and orange shoes'],
#  ['486', 'A dirty commercial kitchen with a bowl on the counter'],
#  ['333135', 'a double deckered transit bus on a city street'],
#  ['207108', 'Some boys are getting slices of a pizza'],
#  ['558736',
#   'Statues of animals stand in a zoo-like display with plants and rocks.'],
#  ['409364', 'a female skateboarder in a black shirt '],
#  ['18022', 'Two brown horses with white manes in a field.'],
#  ['534308', 'some elephants in their pen and some trees'],
#  ['311510',
#   'An image is digitally changed to show a section missing from a parked car.'],
#  ['436875', 'A toilet in a bathroom next to a plunger and trash can.'],
#  ['246069', 'Some vegetables are on a wooden table and stuff.'],
#  ['542509', 'a desk with multiple monitors keyboards and laptops'],
#  ['371549',
#   'there are lots of pieces of tape on the floor and a pair of scissors'],
#  ['124983', 'LIGHT POLE REACHING INTO A BLUE AND CLOUDY SKY'],
#  ['83836', 'A man standing in a kitchen with several bottles on the counter.'],
#  ['213773', 'a close up of a woman wearing a shirt and tie'],
#  ['287545', 'A couple of giraffe standing in a building.'],
#  ['126974', 'A man and woman sit using laptop computers.'],
#  ['194756', 'A man driving a boat down a river next to shore.'],
#  ['435751',
#   'The bench on the beach is getting hit with the waves of the water.'],
#  ['545289', 'A finger that is pointing at bread on a plate.'],
#  ['173008',
#   'A man wearing a Hawaiian shirt eats a banana instead of pastries.'],
#  ['475685', 'A man riding skis across snow covered ground.'],
#  ['81594', 'A woman with an umbrella standing on a deck. '],
#  ['388858', 'Kids on surfboards riding a wave back to the shoreline.'],
#  ['513670', 'A bunch of people flying kites while on a grassy field.'],
#  ['428105', 'Two pizzas on trays cook in an oven'],
#  ['138890', 'a little league player who has just swung his bat'],
#  ['521692', 'A ground level shot of someone standing around in there skis.'],
#  ['345618', 'A simple meal with chicken , greens and cranberry sauce.'],
#  ['127496', 'a bathroom with a toilet a sink and a bath tub'],
#  ['41570', 'People riding scooters down a busy street in Asia.'],
#  ['341128', 'When the pasture is covered with snow, these sheep eat hay.'],
#  ['490081', 'a person riding a carriage being pulled by bulls'],
#  ['581717', 'A white cat is hiding in a bag'],
#  ['354547', 'a man in a white suit standing in front of some bushes '],
#  ['301753', 'Some players in action on a baseball field.'],
#  ['403425', 'A herd of zebra walking across a dry grass field.'],
#  ['156751', 'Flamingos outside in a very grassy green area.'],
#  ['295303', "A child eats a cake in it's high chair."],
#  ['448511', 'A dish of rice and vegetables on a white plate.'],
#  ['88988', 'Kitchen area with appliances and cabinets with missing doors.'],
#  ['432038', 'A dog is chasing some sheep on the grass.'],
#  ['158957', 'A parasurfer dressed in black holding a white colored board.'],
#  ['172995', 'The eater enjoys the hot dog decorated with the pickle.'],
#  ['384402',
#   "A motorcyclist's head is reflected as he rides in his side mirror."],
# ...
#   'Woman walking and talking on a cellphone next to several posted flyers.'],
#  ['151516', 'A bird swooping down to the water to catch food.'],
#  ['433499', 'A small train engine pulling a freight car'],
#  ['165589', 'a blender sits on a counter top unplugged'],
#  ['383777', 'A man standing on a bicycle with a smile.'],
#  ['258061', 'A man wearing a wet suit while surfboarding. '],
#  ['21361', 'White stuffed polar bear positioned in front of a laptop'],
#  ['424998',
#   'An old black and white picture of a tall building with several cars parked alongside in the street.'],
#  ['12147',
#   'A skateboarder practices jumping using a wooden ramp inside a garage.'],
#  ['104629',
#   'A boat in the ocean with several people on it with a flag on it. '],
#  ['51948', 'Two zebra standing next to each other on a  hillside.'],
#  ['568115', 'small city street scene with traffic signals at intersection.'],
#  ['15581', 'A man with a beard is wearing a suit and tie.'],
#  ['10793', 'a red train parked in front of a train station.'],
#  ['3832', 'A large boat and two smaller boats in a row. '],
#  ['381587', 'Assortment of finished meals displayed on a table.'],
#  ['165157', 'A cracked and broken blue Frisbee lying on the grass.'],
#  ['82085', 'A man stands near a passenger train holding a flag.'],
#  ['278512', 'A small white plane sitting on top of an airport runway.'],
#  ['31019', 'A crowd of people walking down a street next to a traffic light.'],
#  ['496845', 'A pickup truck tows a motorboat behind it.'],
#  ['406616', 'The carrots and apple have been sliced on the cutting board.'],
#  ['554828', 'A group of geese are walking down the parking lot. '],
#  ['444236', 'A double decker bus riding on a street on a cloudy day. '],
#  ['252929', 'a  group of kids standing next to paper kites'],
#  ['189451', 'A mostly eaten chocolate cake with one slice left. '],
#  ['339019', 'Many people laying and playing on a beach and in the water.'],
#  ['183319', 'There is a glass of wine next to a computer'],
#  ['392365', 'Men on a baseball team standing together on the playing field.'],
#  ['253455', 'PEOPLE WAITING FOR THE ARRIVAL OF THEIR LUGGAGE IN AN AIRPORT. '],
#  ['185922', 'a bunch of motorcycles parked beside a building '],
#  ['526030', 'Cupcakes cool on top of the stove in the kitchen.'],
#  ['80357', 'A piece of half-eaten cake sits on a plate.'],
#  ['277048', 'Two taxis parked next to each other in the street.'],
#  ['219393', 'SEVERAL YOUNG BOYS ON A COURT PLAYING TENNIS'],
#  ['153217', 'A cat walks next to a motorcycle on a sidewalk. '],
#  ['529917',
#   'A group of people stand together in a room all dressed formally and all in black.'],
#  ['578813', 'the person is coming down the hill on a snowboard'],
#  ['525202',
#   'A pizza sitting on a pizza stand on a table with a checkered cloth.'],
#  ['40842', 'Computer screen displaying a page of small print. '],
#  ['9628', 'A man is in the air while sitting on a surf board.'],
#  ['319283', 'A knife and fork on a plate of pizza topped with arugula.'],
#  ['252444', 'Skateboarders doing stunts in an outdoor skate park.'],
#  ['188386', 'Two men sitting on the ground in the woods. '],
#  ['391688', 'A skateboarder doing tricks on a hand rail while people watch.'],
#  ['138728',
#   'There are many people standing around while a guy catches a frisbee.'],
#  ['334686', 'A girl eats doughnuts in front of a boy'],
#  ['453178',
#   'Broccoli, carrots, and cauliflower being stir fried in a black skilet'],
#  ['205542', 'a teddy bear sitting on some kind of seat.'],
#  ['102906', 'A street devoid of traffic surrounded by tall buildings.'],
#  ['532145', 'seven brown and white cows in a fenced in area'],
#  ['102843', 'A small boat is seen approaching a red lighthouse.'],
#  ['183735', 'A dish filled with black olives next to a bottle of wine.'],
#  ['511713', 'Vintage WW2 fighter plane flying below modern jet.'],
#  ['6437', 'a close up of a polar bear drinking water'],
#  ['178403', 'A cake is on a table under a glass dome.'],
#  ['260808',
#   'A birthday cake shaped like a tree stump with four bears having a party.'],
#  ['334975', 'A bench sits next to a sidewalk adjacent to a street. '],
#  ['161347', 'An airport terminal looking out windows at a parked plane.'],
#  ['102331', 'A professional photograph of a motorcycle rider in the air.'],
#  ['126141', 'Four teddy bears sitting up on a couch.'],
#  ['78113', 'a fire truck turning towards another street by some trees '],
#  ['164883', 'A man holding his face up to a TV with a video game on display.'],
#  ['215151', 'A man flying through the air while riding a skateboard.'],
#  ['519094',
#   'A grey and white cat next to a blanket and shelf with blue bottle.'],
#  ['38259', 'A plane is preparing to load its passengers.'],
#  ['366137', 'The woman who is wearing the jacket is smiling.'],
#  ['90373', "A city bus has it's running lights on at dusk."],
#  ['429074', 'A white toilet sitting in the corner of a bathroom.'],
#  ['573753', 'A cat that is laying on top of someone sleeping in bed.'],
#  ['306073', 'A boy and two females standing in a circle playing tennis.'],
#  ['214463', "A sink that has a container for toothbrushes on it's edge."],
#  ['69000', 'A man and woman sitting together on a bench.'],
#  ['256035', 'A woman racing on skis in the snow.'],
#  ['351967', 'Yellow taxi speeding by a building with many clocks.'],
#  ['241726', 'A pole that has a clock on top of it.'],
#  ['387362', 'a man taking a selfie in a little bathroom mirror '],
#  ['159606', 'A elegant bedroom featuring natural wood and a large window.'],
#  ['327769', 'A cat lying down in a sink in a bathroom.'],
#  ['230739', 'A large group of boats in the water next to a city.'],
#  ['491965',
#   'A bus sits parked outside of a building with desert landscaping.'],
#  ['304396',
#   "Salmon-colored clock tower with Florida architectural features including a window's walk."],
#  ['570947', 'A half sliced cheese pizza near a fork, a knife, and a glass.'],
#  ['226008', 'These two women are hurtling through the water on a Jet Ski.'],
#  ['524694', 'A giraffe examines a rock in its enclosure.'],
#  ['541744',
#   'A batter holds his bat up in front of the catcher and umpire during a baseball game with full stands.'],
#  ['323602',
#   'A grey and white puppy wearing a bandana stands on a skateboard.'],
#  ['121041', 'A black duck floating in a wavy pond.'],
#  ['575637', 'A man paddles a boat while his passenger relaxes in the back.'],
#  ['319721', 'The woman stands next to the large brown horse.'],
#  ['19443', 'A motorcycle sitting on top of a fence as decor'],
#  ['490199', 'Two people sit in the bed of a pickup truck holding dogs.'],
#  ['208423', 'A distant view of several kites flying in the air.'],
#  ['498061', 'A man wearing glasses smiling in a restaurant setting.  '],
#  ['273914',
#   'There is a silver double decker bus with words printed on the side of it.'],
#  ['361481', 'a plate of chilies with carrots and peas'],
#  ['118739', 'Large pizza pie with one slice missing on the table'],
#  ['183407', 'A MIRROR OF A BIKE IN THE GRASS '],
#  ['448278', 'A pond with various birds and ducks swimming.'],
#  ['219260', 'An old fashioned passenger train drives down a track.'],
#  ['483348', 'A white toilet sitting next to a toilet paper roller.'],
#  ['134863', 'A couple of traffic lights hanging over a city street.'],
#  ['574138', 'A man preparing food on a large counter.'],
#  ['1146', 'A person that is dressed up very nicely.'],
#  ['546773',
#   'A man and child, each wearing an umbrella hat, hold hands as they walk. '],
#  ['91766', 'a table full of fruits, vegetables, and egss'],
#  ['219629', 'a little boy that is eating some kind of doughnut'],
#  ['383594', 'A sandwich on a plate with pickles and onion.'],
#  ['256367', 'A train travelling on the train tracks near the woods. '],
#  ['17115', 'A rear view of two zebras with their heads up against a fence.'],
#  ['199771', 'A group of people in chefs uniforms standing around a counter.'],
#  ['283187', 'A man falls down as another catches the Frisbee.'],
#  ['460652', 'A stop sign with white stickers all over it.'],
#  ['387082',
#   'A man with a green shirt boarding a blue and orange bus across the street from apartment buildings. '],
#  ['492608', 'A surfer catches a wave in the ocean.'],
#  ['328286', 'Boats docked at a harbor facing the city.'],
#  ['39267', 'A woman sitting on a bathroom floor leaning over a toilet.'],
#  ['137811',
#   'Two standing zebras both looking in opposite ways from each other.'],
#  ['443952', 'Inside of a bathroom with a sink and toilet.'],
#  ['328', 'Three men in military suits are sitting on a bench,'],
#  ['210404', 'A cake decorated to look like a teddy bear.'],
#  ['364188', 'A young child holding an electric toothbrush in its mouth.'],
#  ['511241',
#   'A dinner table with beverages and dishes of chickpeas, rice, greens, and soup.'],
#  ['205089', 'A hotel bedroom that has a bed and tv and furniture.'],
#  ['3425', 'A room with various items on the bed and nightstand'],
#  ['372413',
#   'Onlookers are watching a pair doing tricks on their motorcycle. '],
#  ['194940', 'Three bowls filled with vegetables on top of a table.'],
#  ['473731', 'A picture of a horse that is in some dirt.'],
#  ['13473', 'The man is covering his face with the mug.'],
#  ['321008', 'A waffle on a plate topped with fruit.'],
#  ['390052', 'THERE ARE CHLDREN OUT ON THE GRASS PLAYING GAMES'],
#  ['190391', 'A very tasty looking hot dog with mustard on it.'],
#  ['487698', 'A woman on a cell phone running by a fire hydrant.'],
#  ['33815',
#   'A man riding a motorcycle down a street with people sitting on the curb, watching.'],
#  ['44361', 'A VERY ELEGANT LOOKING WHITE BATHROOM WITH HUGE TUB.'],
#  ['37777', 'The dining table near the kitchen has a bowl of fruit on it.'],
#  ['415585', 'A train on tracks in a city with high rises.'],
#  ['467956', 'Meat, broccoli and potatoes artfully served on a white plate'],
#  ['318346', 'A taco salad sits on white paper near a table with a lap top.'],
#  ['59732', 'a number of cars on a street with traffic lights '],
#  ['370900', 'Four stuffed bears have crowns on their heads.'],
#  ['551338', 'A woman standing in a park holding a yellow frisbee.'],
#  ['330720', 'A teal colored clock with little men on top. '],
#  ['451943',
#   'Queen size bed with grey and beige linens in a room with wood flooring.'],
#  ['86913', 'A person hitting a tennis ball with a tennis racquet'],
#  ['437332', 'a man standing on a skateboard and leaning off to the side'],
#  ['205333', 'A couple skiers on a snowy mountain side'],
#  ['30942', 'Two unattended motorcycles parked somewhere near a red car.'],
#  ['158849', 'A crowd of people standing next to each other with luggage.'],
#  ['110617', 'A baseball player in a ball hitting stance.'],
#  ['355057', 'The wing of an airplane with mountains in the background.'],
#  ['148668', 'A bicycle can be seen parked next to a light pole.'],
#  ['66413', 'a cat sleeping on the floor with a little toy'],
#  ['42008', 'A truck is parked on the side of a road near a bus.'],
#  ['382172', 'Horse stands in field with jacket on it looking to camera'],
#  ['379800', 'Train engine pulling one freight car along rails'],
#  ['214463',
#   'a close up of a bathroom sink with soap and tooth brushes in a cup'],
#  ['577862', 'Two giraffes standing next to each other in a holding pen. '],
#  ['475879', 'a bag of luggage resting on the floor.'],
#  ['208377', 'The man is walking into the ocean with  a sailboard.'],
#  ['220214', 'an image of a train that is going down the tracks'],
#  ['317310', 'an oss secoration of a bear committing suicide in a tub'],
#  ['174070', 'A teddy bear sitting in a window holding a cell phone.'],
#  ['430867',
#   'A woman sitting on a bench with a dog sitting on the ground by her.'],
#  ['352005', 'A guy is wearing a suit and tie posing for the camera.'],
#  ['430788', 'A white horse stands at the side of a road, pulling a carriage.'],
#  ['531739', 'A happy bus driver looks down at his fare collector'],
#  ['352587', 'Two horses graze in a grassy pasture lined with pine trees.'],
#  ['516766', 'A stuffed white bear attached to a smaller one'],
#  ['47624', 'Three children dressed in white holding tennis rackets.'],
#  ['42622', 'A man on a surfboard in the water.'],
#  ['389644', 'people having a cookout celebration in their backyard'],
#  ['365207', 'A couple of red cars parked in front of a house.'],
#  ['328018', 'A bird is perched on a log next to the water.'],
#  ['12706', 'A crowd of people standing below the Eiffel tower.'],
#  ['350148', 'A man taking a pic of a sandwich on a table'],
#  ['277592', 'A giraffe is standing in a lot behind two rocks.'],
#  ['521292', 'A woman is talking on a phone outside.'],
#  ['514731', 'A little boy sharing a hoodie with a teddy bear.'],
#  ['325239', 'a lady that is at a sink in a kitchen'],
#  ['444576', 'A man with a dog driving in his green convertible. '],
#  ['389123', 'two people in a small boat in a body of water'],
#  ['36660',
#   'A woman with pretty painted toe nails standing in front of a broken cell phone.'],
#  ['58869', 'A man eating raw oysters at a picnic table by the water.'],
#  ['441686', 'Two horses with saddles are galloping close together.'],
#  ['343213', 'A busy corner market with many bicycles parked in front of it.'],
#  ['431521', 'Animals are grazing in a fenced in field.'],
#  ['114744', 'People stand under umbrellas in the rain next to a motorcycle.'],
#  ['192763', 'A yellow fire hydrant with a hat on top.'],
#  ['316258', 'A group of boats that are sitting in the water.'],
#  ['300701', 'Two guys fly a colorful kite next to a large body of water.'],
#  ['211370',
#   'A girl in a red jacket is on a snowboard as the ground is barely covered with snow.'],
#  ['42875', 'A couple of cows resting in a field near the waters edge.'],
#  ['343972', 'A herd of elephants standing next to each other.'],
#  ['306415', 'four men in suits talking near robot model '],
#  ['278705',
#   'This is an image through a window looking at two people on skateboards.'],
#  ['426686', 'A herd of cattle grazing on a brush covered grassy pasture.'],
#  ['397705', 'A man laying in a bed with three cats.'],
#  ['194012', 'A man wearing a suit is looking across the room.'],
#  ['90011', 'a person bending down cutting another persons hair '],
#  ['283277', 'A city street at night lined with street lights.'],
#  ['57150', 'A girl in plain dress standing next to a white teddy bear.'],
#  ['456578',
#   'A woman is holding a pizza in a field in front of an outdoor oven.'],
#  ['75118',
#   'a decorated jet plane flying in the sky leaving a traill of smoke'],
#  ['61515', 'Two bears standing on a grassy hill facing each other. '],
#  ['237501', 'A teddy bear playing a drum and a teddy bear playing a guitar.'],
#  ['182050', 'An open white fridge full of food and drinks. '],
#  ['53958', 'A woman skiing on a large white mountain.'],
#  ['233553', 'two giraffes in  field near some trees '],
#  ['209753', 'The young girl using her cell phone is wearing a glowing belt.'],
#  ['283216', 'Two people pose for a picture while one points at a moped.'],
#  ['31730', 'A white toilet in a bathroom with a digital arm rest.'],
#  ['284885', 'Train traveling on tracks through city near glass buildings.'],
#  ['86884', 'This is a closeup of a brown cake with white frosting.'],
#  ['147806', 'A man is taking a selfie of himself at the salon.'],
#  ['341164', 'a man in a hat riding a skateboard on a street'],
#  ['419216', 'some people are sitting outside in chairs with umbrellas'],
#  ['207003',
#   'Two people on the ground with large balloons of an orange and white fish and a crab, floating in the sky.'],
#  ['278627', 'A series of photos showing people eating food.'],
#  ['454818', 'A large brown dog laying inside of a car.'],
#  ['88286', 'a person on a skate board getting pushed by someone else '],
#  ['308026', 'A person riding his skateboard on cement steps.'],
#  ['285614', 'A small toy riding a skateboard next to a miniature ramp.'],
#  ['462244', 'A train sitting on the railroad tracks. '],
#  ['412975', 'A girl walks on the side of a crowded street.'],
#  ['503855',
#   'A park with yellow umbrellas on the grass and onlookers in the background.'],
#  ['378751', 'A cat sprawled out on a couch with a remote on the arm'],
#  ...]
