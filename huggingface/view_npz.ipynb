# %%
import os
os.chdir('../')

# %%
ls samplings/dit256_dpms10/samples_arr0_256x256x3_uint8.npz
# Out:
# samples_arr0_256x256x3_uint8.npz  samples_png/

# %%
import numpy as np

data = np.load('samplings/dit256_dpms10/samples_arr0_256x256x3_uint8.npz')
data.keys()
# Out:
# KeysView(NpzFile 'samplings/dit256_dpms10/samples_arr0_256x256x3_uint8.npz' with keys: arr_0)

# %%
data['arr_0'].shape
# Out:
# (50000, 256, 256, 3)
